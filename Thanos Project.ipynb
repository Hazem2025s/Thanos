# %% [markdown]
# - Make a copy of the Universe images in the backup folder.
# - make a function to kill half the images randomly.
# - call the func several times to kill the entire population( half the number of images each time).
# - Import the images again to the universe folder from the backup folder.
# - Create another folder and take a copy from the images with different random names consisting of 5 letters.

# %%
import random
import string
import os
import shutil

os.getcwd()
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover001.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover002.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover003.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover004.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover005.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover006.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover007.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover008.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover009.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover010.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover011.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover012.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover013.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover014.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover015.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover016.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover017.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover018.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover019.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\universe\\cover020.png','d:\\Computer\\Project thanos\\Thanos Project\\backup')


def kill_half(folder1):
    images = os.listdir(folder1)
    half = len(images) //2 # to get half
    images_del = random.sample(images, k=half) # select images to delete withoud duplicates
    for image in images_del:
        os.remove(os.path.join(folder1,image))
        
folderPath= 'd:\\Computer\\Project thanos\\Thanos Project\\universe'       

#kill_half(folderPath)

shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover001.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover005.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover006.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover002.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover003.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover007.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover008.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover009.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover011.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover012.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')
shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover013.png','d:\\Computer\\Project thanos\\Thanos Project\\universe')


#os.mkdir('d:\\Computer\\Project thanos\\Thanos Project\\NewFolderr')

os.getcwd()

#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover001.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover002.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover003.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover004.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover005.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover006.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover007.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover008.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover009.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover010.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover020.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover019.png','NewFolderr')
#shutil.copy('d:\\Computer\\Project thanos\\Thanos Project\\backup\\cover018.png','NewFolderr')



os.getcwd()
ran = ''.join(random.choices(string.ascii_lowercase , k=5))

os.rename('NewFolderr\\cover003.png','NewFolderr//{}.png'.format(ran))
